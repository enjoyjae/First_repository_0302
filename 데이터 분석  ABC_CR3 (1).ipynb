# %% [markdown]
# # 데이터 분석 ABC_CR3(Project)
#
#                                             -made by enjoyJae -

# %%
# 필요 라이브러리 호출하기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %%
# 데이터 호출하기
entry_data = pd.read_csv('/aiffel/data/entry_data.csv')
sales_data = pd.read_csv('/aiffel/data/sales_data.csv')
item_data = pd.read_csv('/aiffel/data/item_data.csv')
item_entry_data = pd.read_csv('/aiffel/data/item_entry_data.csv')

# %%
# entry_data 데이터 정보 확인하기
entry_data.head(50)
# Out:
#             요금제명                입실                퇴실           이용    위치    금액  \
# 0     시간요금제(1시간)  2022-04-01 23:39   2022-04-02 0:39   오전 1:00:00  선불기2  3000
# 1     시간요금제(1시간)  2022-04-01 23:39   2022-04-02 0:39   오전 1:00:00  선불기2  3000
# 2        무제한 입장권  2022-04-01 20:55  2022-04-01 21:41  오전 12:46:00  선불기2  7400
# 3        무제한 입장권  2022-04-01 20:55  2022-04-01 21:41  오전 12:46:00  선불기2  7400
# 4   한국대생 무제한 입장권  2022-04-01 19:54  2022-04-01 22:28   오전 2:33:00  선불기2  7400
# 5   한국대생 무제한 입장권  2022-04-01 19:54  2022-04-01 22:28   오전 2:33:00  선불기2  7400
# 6   한국대생 무제한 입장권  2022-04-01 19:54  2022-04-01 22:28   오전 2:33:00  선불기2  7400
# 7   한국대생 무제한 입장권  2022-04-01 19:32  2022-04-01 22:28   오전 2:56:00  선불기2  6400
# 8   한국대생 무제한 입장권  2022-04-01 19:32  2022-04-01 22:28   오전 2:56:00  선불기2  6400
# 9   한국대생 무제한 입장권  2022-04-01 19:32  2022-04-01 22:28   오전 2:56:00  선불기2  6400
# 10  한국대생 무제한 입장권  2022-04-01 19:32  2022-04-01 22:28   오전 2:56:00  선불기2  6400
# ...

# %%
# sales_data 데이터 정보 확인하기
sales_data.head()
# Out:
#                결제일시  판매위치          상품명  결제방식    비고  판매수량   결제금액  \
# 0  2022-04-01 19:41  선불기1   치킨카라아케 6pc  신용카드  결제완료     1  4,500
# 1  2022-04-01 19:41  선불기1   짜장라면(계란추가)  신용카드  결제완료     1  5,500
# 2  2022-04-01 19:41  선불기1           라면  신용카드  결제완료     1  4,000
# 3  2022-04-01 19:41  선불기1   비엔나소세지(토핑)  신용카드  결제완료     1  1,000
# 4  2022-04-01 19:41  선불기1  라면(계란/치즈추가)  신용카드  결제완료     1  5,000
#
#                고객
# 0  customer275507
# 1  customer275507
# 2  customer275507
# 3  customer275507
# 4  customer275507

# %%
# item_data 데이터 정보 확인하기
item_data.head(20)
# Out:
#     구분          분류        상품명    판매금액
# 0    1       게임&TV   이어폰(커널형)  3,000원
# 1    2         디저트       초코머핀  3,500원
# 2    3         디저트    쿠키(초코칩)  1,500원
# 3    4         디저트  쿠키(마카다미아)  1,500원
# 4    5         디저트  미니마카롱(3개)  2,000원
# 5    6         디저트      치즈케이크  4,000원
# 6    7         디저트     블루베리머핀  3,500원
# 7    8         디저트    쿠키(오트밀)  1,500원
# 8    9         디저트        크로플  5,500원
# 9   10         디저트      치즈케이크  1,500원
# 10  11         디저트  미니마카롱(3개)  1,500원
# 11  12         디저트     블루베리머핀  1,500원
# 12  13         디저트    쿠키(초코칩)  1,000원
# 13  14  따뜻한음료(커피외)   청귤차(HOT)  4,500원
# 14  15  따뜻한음료(커피외)  초코라떼(HOT)  4,500원
# 15  16  따뜻한음료(커피외)   유자차(HOT)  4,000원
# 16  17  따뜻한음료(커피외)  카모마일(HOT)  4,000원
# 17  18  따뜻한음료(커피외)  녹차라떼(HOT)  4,500원
# 18  19  따뜻한음료(커피외)   레몬차(HOT)  4,000원
# 19  20  따뜻한음료(커피외)  페퍼민트(HOT)  4,000원

# %%
# item_entry_data 데이터 정보 확인하기
item_entry_data.head()
# Out:
#    순위     분류        상품명    판매금액
# 0   1   한국대생   한국대생 요금제  2,000원
# 1   2  심야-조조  심야-조조 요금제  5,000원
# 2   3    일반인      일반요금제  2,500원
# 3   4   한국대생   한국대생 요금제  2,500원
# 4   5    일반인      일반요금제  2,000원

# %% [markdown]
# # 3-2 데이터 분석하기
# - ## **필수 문제1 : 월별 매출액 추세(sales_data를 이용합니다.)**
#
# 월별 매출액 추세를 집계하고 그 결과를 시각화해봅니다.
# 힌트: groupby() 함수를 사용하세요.

# %%
# 문제 1: 월별 매출액 추세
# 활용할 데이터(sales_data)를 temp_var로 정의하기
temp_var = sales_data
temp_var['결제금액'].dropna().unique()
# temp_var의 date열을 만들고, sales_date의 결제일시 중 앞에서 7번째 값까지 할당
temp_var['date'] = sales_data['결제일시'].str[:7]
temp_var
# Out:
#                   결제일시  판매위치          상품명  결제방식    비고  판매수량    결제금액  \
# 0     2022-04-01 19:41  선불기1   치킨카라아케 6pc  신용카드  결제완료     1   4,500
# 1     2022-04-01 19:41  선불기1   짜장라면(계란추가)  신용카드  결제완료     1   5,500
# 2     2022-04-01 19:41  선불기1           라면  신용카드  결제완료     1   4,000
# 3     2022-04-01 19:41  선불기1   비엔나소세지(토핑)  신용카드  결제완료     1   1,000
# 4     2022-04-01 19:41  선불기1  라면(계란/치즈추가)  신용카드  결제완료     1   5,000
# ...                ...   ...          ...   ...   ...   ...     ...
# 7100  2021-02-17 14:21   카운터   아메리카노(HOT)    현금  결제취소    -1  -3,500
# 7101  2021-02-17 13:51  선불기2    카페모카(HOT)  신용카드  결제완료     1   4,500
# 7102  2021-02-17 13:51  선불기2    카페모카(HOT)  신용카드  판매취소    -1  -4,500
# 7103  2021-02-17 13:26   카운터    카페라떼(HOT)  신용카드  결제완료     1   4,000
# 7104  2021-02-17 13:27   카운터    카페라떼(HOT)  신용카드  판매취소    -1  -4,000
#
#                   고객     date
# 0     customer275507  2022-04
# 1     customer275507  2022-04
# 2     customer275507  2022-04
# ...

# %%
# sales_data의 결제금액에 포함된 쉼표(,) 지우기
temp_var['결제금액'] = temp_var['결제금액'].str.replace(',', '')
temp_var

# sales_data의 결제금액을 숫자형태로 바꾸기
temp_var['결제금액'] = pd.to_numeric(temp_var['결제금액'])
temp_var

# temp_var의 payment열을 date 기준으로 집계하기
payment_data = temp_var['결제금액'].groupby(temp_var['date']).sum()

# %%
payment_data
# Out:
# date
# 2021-02       7000
# 2021-03    2104500
# 2021-04    3116600
# 2021-05    2537000
# 2021-06    3621500
# 2021-07    1215000
# 2021-08    1229000
# 2021-09    1197500
# 2021-10    2138500
# 2021-11    2748500
# 2021-12    3290000
# 2022-01    1430500
# 2022-02    1181500
# 2022-03    1870900
# 2022-04      49900
# Name: 결제금액, dtype: int64

# %%
# 집계 결과를 시각화하기
plt.bar(payment_data.index, payment_data)
plt.xlabel("Month")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.title('Sales By Months')
plt.show()

# %% [markdown]
# - ## **필수 문제2: 가장 인기 있는 음식/음료(sales_data를 이용합니다.)**
#
# 여러 메뉴들(음식,음료)을 판매 개수 순으로 정렬하고 상위 10개를 뽑아 결과를 시각화해봅니다.
# 힌트: value_counts() 함수를 사용하세요.

# %%
# 문제 2: 가장 인기 있는 음식/음료
# temp_var의 상품명을 value_counts를 이용해 집계하기
# 주의! value_counts로 바로 집계하면 판매취소와 결제취소가 함께 집계됩니다.
# 따라서 '판매수량' 칼럼 값이 '-1'인 데이터를 제외하고 집계해야 합니다.
# 힌트 코드 : temp_var[temp_var['판매수량']==-1]
temp_var = temp_var[temp_var['판매수량'] !=-1]
temp_var['상품명'].value_counts()
# Out:
# 김치볶음밥          1204
# 라면              749
# 짜장라면            455
# 치즈불고기볶음밥        420
# 계란추가            314
#                ...
# 라면(계란/치즈추가)       1
# 녹차(HOT)           1
# 짜장라면(계란추가)        1
# 이어폰(커널형)          1
# 오늘은 한돈간장불고기       1
# Name: 상품명, Length: 100, dtype: int64

# %%
# 집계 결과를 데이터프레임으로 변환하고, 상위 10개 선정하기
items_count = pd.DataFrame(temp_var['상품명'].value_counts())
items_count.reset_index(inplace = True)
items_count.columns = ['상품명', '집계수량'] 
items_count = items_count.sort_values(by=['집계수량'], ascending=False) 
items_count.head(10)
# Out:
#           상품명  집계수량
# 0       김치볶음밥  1204
# 1          라면   749
# 2        짜장라면   455
# 3    치즈불고기볶음밥   420
# 4        계란추가   314
# 5       낙지볶음밥   312
# 6       새우볶음밥   309
# 7  아메리카노(ICE)   284
# 8      치즈감자튀김   246
# 9        감자튀김   242

# %%
items_count
# Out:
#             상품명  집계수량
# 0         김치볶음밥  1204
# 1            라면   749
# 2          짜장라면   455
# 3      치즈불고기볶음밥   420
# 4          계란추가   314
# ..          ...   ...
# 95  라면(계란/치즈추가)     1
# 96      녹차(HOT)     1
# 97   짜장라면(계란추가)     1
# 98     이어폰(커널형)     1
# 99  오늘은 한돈간장불고기     1
#
# [100 rows x 2 columns]

# %%
# 한글이 포함된 시각화를 위해 Matplotlib 설정
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager.findfont(font)
print("완료!")
# Out:
# 완료!

# %%
# 집계 결과를 시각화하기
plt.bar(items_count.head(10)['상품명'], items_count.head(10)['집계수량'])
plt.ylabel("집계수량",fontsize = 20)
plt.xlabel("상품명",fontsize = 20)
plt.title('판매개수',fontsize = 20)
plt.xticks(rotation=90)
plt.show()

# %%
# temp_var의 payment열을 상품명을 기준으로 집계하기
items_payment = temp_var['결제금액'].groupby(temp_var['상품명']).sum()

items_payment = pd.DataFrame(items_payment)
items_payment = items_payment.sort_values(by=['결제금액'], ascending=False)
items_payment.reset_index(inplace=True)
items_payment
items_payment['결제금액'] = pd.to_numeric(items_payment['결제금액'])
items_payment = items_payment.head(10)

# %%
items_payment
# Out:
#           상품명     결제금액
# 0       김치볶음밥  6004400
# 1          라면  2941500
# 2    치즈불고기볶음밥  2292600
# 3        짜장라면  2038500
# 4       낙지볶음밥  1710700
# 5       새우볶음밥  1539800
# 6      치즈감자튀김  1354200
# 7        감자튀김  1083800
# 8  아메리카노(ICE)  1058100
# 9       불닭볶음면   693000

# %%
# 집계 결과를 시각화하기
plt.bar(items_payment['상품명'], items_payment['결제금액'])
plt.ylabel("원",fontsize = 20)
plt.xlabel("상품명",fontsize = 20)
plt.title('판매금액',fontsize = 20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - ## **필수 문제3: 가장 많이 팔린 입장권 종류(entry_data를 이용합니다.)**
#
# 여러 입장권 종류를 판매 매출(판매 개수 x 금액) 순으로 정렬하고 상위 10개를 뽑아 결과를 시각화해봅니다.
# 힌트: value_counts() 함수를 사용하세요.

# %%
# 문제 3: 가장 많이 팔린 입장권 종류
# 활용할 데이터(entry_data)를 temp_var로 정의하기
temp_var = entry_data

# # temp_var의 금액을 숫자형태로 변환하기
temp_var['금액'] = pd.to_numeric(temp_var['금액'])

# # temp_var의 금액을 요금제명을 기준으로 집계하기
tickets = temp_var['금액'].groupby(temp_var['요금제명']).sum()

# # tickets의 값을 내림차순으로 정렬하고 상위 10개 도출하기
tickets = pd.DataFrame(tickets)
tickets['금액'] = pd.to_numeric(tickets['금액'])
tickets = tickets.sort_values(by=['금액'], ascending=False)
tickets.reset_index(inplace=True)
tickets.head(10)
# Out:
#               요금제명        금액
# 0    한국대생 입장권(종일권)  70037000
# 1         입장권(종일권)  23570500
# 2  심야-조조무제한(06시까지)  11600000
# 3         심야-조조무제한   6221000
# 4     한국대생 무제한 입장권   5207500
# 5       시간요금제(1시간)   2665500
# 6       시간요금제(3시간)   2042000
# 7          무제한 입장권   1568600
# 8        18시이후 무제한   1330500
# 9            조조무제한    693000

# %%
# 집계 결과 시각화하기
plt.bar(tickets.head(10)['요금제명'], tickets.head(10)['금액'])
plt.xlabel("요금제명")
plt.ylabel("원")
plt.title('입장권별 판매금액')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - ## 내가 정의한 문제 해결하기
#
# 나는 이번 프로젝트에서 (------)을 알아내겠다 -> 나는 이번 프로젝트에서 (VIP 고객들의 특성/특징)을 알아내겠다

# %%
# 내 Key Question을 중심으로 다양한 분석을 진행해봅시다.
"""
나는 이번 프로젝트에서 (주요 고객들(한국대생의 특성/특징)을 알아내겠다
(이유: 스타디 카페의 고정적인 수입원인 VIP고객들을 안정적으로 잡기 위해)
"""
temp_var = entry_data
temp_var
# Out:
#                요금제명                입실                퇴실           이용    위치  \
# 0        시간요금제(1시간)  2022-04-01 23:39   2022-04-02 0:39   오전 1:00:00  선불기2
# 1        시간요금제(1시간)  2022-04-01 23:39   2022-04-02 0:39   오전 1:00:00  선불기2
# 2           무제한 입장권  2022-04-01 20:55  2022-04-01 21:41  오전 12:46:00  선불기2
# 3           무제한 입장권  2022-04-01 20:55  2022-04-01 21:41  오전 12:46:00  선불기2
# 4      한국대생 무제한 입장권  2022-04-01 19:54  2022-04-01 22:28   오전 2:33:00  선불기2
# ...             ...               ...               ...          ...   ...
# 22550         종일요금제  2021-02-17 13:09  2021-02-17 14:19   오전 1:10:00  선불기1
# 22551         종일요금제  2021-02-17 13:09  2021-02-17 14:19   오전 1:10:00  선불기1
# 22552         종일요금제  2021-02-17 13:06  2021-02-17 14:19   오전 1:13:00  선불기1
# 22553         종일요금제  2021-02-17 13:06  2021-02-17 14:19   오전 1:13:00  선불기1
# 22554         종일요금제  2021-02-17 12:58  2021-02-17 14:19   오전 1:21:00  선불기1
#
#          금액  구분              고객
# 0      3000  퇴실  customer263717
# ...

# %%
# 1. 주요 고객(한국대생 입장권(종일권)) 데이터 만 추출
temp_var = temp_var[temp_var['요금제명'] == '한국대생 입장권(종일권)']
temp_var = pd.merge(temp_var, sales_data, on = '고객', how = 'left')

# %%
# 2.주요 고객(한국대생 입장권(종일권))의 월별  소비 트렌드 
temp_var['금액'] = pd.to_numeric(temp_var['금액'])
temp_var['date'] = temp_var['입실'].str[5:7]
temp_var['date'] = pd.to_numeric(temp_var['date'])


# # temp_var의 금액을 date 기준으로 집계하기
payment = pd.DataFrame(temp_var['금액'].groupby(temp_var['date']).sum())
payment.reset_index(inplace=True)
payment = payment.sort_values(by=['date'], ascending=False)
payment

# 집계 결과를 시각화하기
plt.bar(payment['date'], payment['금액'])
plt.ylabel("원",fontsize = 20)
plt.xlabel("월",fontsize = 20)
plt.title('소비금액',fontsize = 20)

ticklabel=payment['date']
plt.xticks(ticklabel)
# plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 이전 전체 고객을 넣었을 땐 (2-6월,10-12월)이 가장 많은 소비가 이루워 졌는데
# 한국대생의 고객 데이터를 넣었을땐 월별 소비가 비슷한 경향은 있었지만
# 2월의 소비는 낮게 나왔다.
#
# 따라서 2월에는 주요 고객층이 한국 대생이 아닌 다른 소비 집단으로 판단 되어 진다.
# (2월의 주요 고객을 알아내고 그에 따른 전략 수정이 필요해 보여진다)
# 또한 1-3월 7-9월은 방학기간으로 다른 소비자들을 마케팅할 방식이 필요해 보인다.

# %%
#3.주요 고객(한국대생 입장권(종일권))의 상품 선호도 
temp_var= temp_var[temp_var['판매수량'] !=-1]
temp_var['상품명'].value_counts()

items_count = pd.DataFrame(temp_var['상품명'].value_counts())
items_count.reset_index(inplace = True)
items_count.columns = ['상품명', '집계수량'] 
items_count = items_count.sort_values(by=['집계수량'], ascending=False) 
items_count.head(10)

# 집계 결과를 시각화하기
plt.bar(items_payment['상품명'], items_payment['결제금액'])
plt.ylabel("원",fontsize = 20)
plt.xlabel("상품명",fontsize = 20)
plt.title('판매금액',fontsize = 20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 아무래도 주요 소비층이 한국대생이였다 보니 이전 전체 고객을 넣었을 때와 비슷한 상품 소비 성향이 나왔다.

# %% [markdown]
# # 회고
# 이번 시간에는 데이터 분석을 다루는 실습을 진행하였는데
# 실제 실무에서 사용될만한 코드들을 많이 배워서 흥미로웠다..
# 현재 가지고 있는 실험 데이터(빅데이터)를 분석할때 사용 하면 평소 엑셀로만 분석할때 보다 더 효율적이고
# 빠르게 분석을 실시 할 수 있을것 같다.
#
# - 아쉬운점
#     - 코드들이 익숙하지가 않아서 사용하는데 자꾸 버퍼링이 걸렸다. 자주 사용해 보아야 겠다.
#     - 나의 도메인이 아니더라도 창의적인 분석 시야를 넓힐 수 있게 다양한 도메인 데이터를 다뤄봐야겠다.
